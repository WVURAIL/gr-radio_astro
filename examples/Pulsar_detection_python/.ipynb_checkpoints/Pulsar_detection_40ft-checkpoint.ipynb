# %%
# %matplotlib notebook
import numpy as np
from matplotlib.pyplot import *
import gc
from scipy import signal
import h5py
# Out:
# /home/andy/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
#filename = "/home/andy/testfile.h5"
filename2 = "/home/andy/testfile2.h5"
#fiel = h5py.File(filename, 'r')
fiel2 = h5py.File(filename2, 'r')
#list(fiel.keys())

# %%
timestamps = list(fiel2['timestampNs'])

# %%
#pulse_data = list(fiel['timestream'])
pulse_data2 = np.asarray(list(fiel2['timestream']))

# %%
pulse_data21=np.fft.fftshift(pulse_data2.real)

# %%
pulse_data2 = pulse_data2.real

# %%
np.mean(diff)
diff[-1]-diff[-2]

# %%
for i in range(4080):
    if np.max(pulse_data2[:,i])>20000:
        pulse_data2[:,i]=0

for i in range(4080):
    if np.max(pulse_data21[:,i])>20000:
        print(i)
        pulse_data21[:,i]=0
# Out:
# 2032
# 2033
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2047
# 2048

# %%
figure()
imshow(pulse_data21[:], aspect='auto')
colorbar()

# %%
figure()
plot(pulse_data21[:,2032])

# %%
#
#
#

#This is the pulsar period

1/4080*80000*4.0

#
#
#

# %%
5*60/(.004080)
# Out:
# 73529.41176470587

# %%
added_fft1 = np.sum(pulse_data21[14705:73529], axis=1)
added_fft2 = np.sum(pulse_data21[90000:], axis=1)

# %%
#pulse_array = np.asarray(pulse_data2)
#pulse_array = pulse_array[0:110544-976]

# %%
fft_data1 = (np.fft.fft(added_fft1, norm="ortho"))
fft_data2 = (np.fft.fft(added_fft2))

# %%
figure()
plot(np.linspace(0,245.09803921568627,73529-14706),abs(fft_data1[1:])*10*4.5)
figure()
plot(np.linspace(0,245.09803921568627,123489-90001),abs(fft_data2[1:]))
figure()
plot(abs(fft_data1[1:33489])*10*4/abs(fft_data2[1:]))
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
#The number of bins that the 
period = .714519
all_pulse = np.zeros([int(80000/800),4070])
count_phase = np.zeros([int(80000/800),4070])
period_bins = 700
timestamp=0
pulse_dats= pulse_data21[:80000, 0:4070]
for i in range(80000):
    #Here, the phase will be found as a percentage of the overall period yb using the time
    phase = np.int(80000/800*np.modf(.00408*i/period)[0])
    #This adds together all of the data which is contained in the same phase of the pulsar
    all_pulse[phase,:] += pulse_dats[i,:]
    #This counts how many times the pulse was looped over, so that
    #The amount of times that a pulse is added to a speciefic value is noted here
    count_phase[phase,:]+=1

# %%
new_pulse = all_pulse/count_phase

# %%
80000/10
# Out:
# 8000.0

# %%
figure()
imshow(pulse_dats, aspect="auto")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
pulse_freqs = 10/4096*np.arange(0,4096)
d_t_int= 4.08
dmk = 4148808/d_t_int
inv_f_low_sq = 1/(1420-5)**2
de_pulse = np.zeros((100,4070))
for j in range(4070):
    shift = -round( dmk * 28.3 * (inv_f_low_sq - 1/((10*j/4070 + (1420-5))**2 )))
    for k in range(100):
        y = (k-shift) % 100
        de_pulse[k,j] = new_pulse[y,j]

# %%
#figure()
#plot(np.sum(new_pulse, axis=1))
figure()
plot(np.sum((de_pulse[:,:]/np.mean(de_pulse)/4070), axis=1))
xlabel("Period")
ylabel("amplitude")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0,0.5,'amplitude')

# %%
(de_pulse[:,:]/np.mean(de_pulse)/4070)
# Out:
# array([[0.00012958, 0.0001301 , 0.00012676, ..., 0.00012725, 0.00012966,
#         0.00013379],
#        [0.00012651, 0.00012745, 0.00013103, ..., 0.00012972, 0.00012837,
#         0.00013114],
#        [0.00013169, 0.00012558, 0.00012528, ..., 0.00012933, 0.00013098,
#         0.00012642],
#        ...,
#        [0.00012851, 0.00012863, 0.00012718, ..., 0.00013061, 0.00012784,
#         0.00013162],
#        [0.0001309 , 0.00012664, 0.00012992, ..., 0.00012796, 0.00013011,
#         0.00012616],
#        [0.00013182, 0.00012542, 0.00012956, ..., 0.00012808, 0.00012802,
#         0.00012634]])

# %%
n_frequencies = np.fft.fftfreq(step, 1/(10e6/1e6)) #This is the number of frequency channles.The first parameter 
                                #should be the number of chanels desired, and the second is the sample rate in MHz.
                                #This will lable the the x axis
pulse_freqs = np.fft.fftshift(n_frequencies)+Cf/1e6 #This will place the centre frequency of the plot at 1400MHz
dispersed = np.flip(np.transpose(np.fft.fftshift((rec_spect))), 0)#The array of the data must be flipped to match 
                                    #the units in the plot,and it must be transposed so that time is on the x axis.
bb_flipped = np.flip(np.transpose(np.fft.fftshift(bb_noise)),0)

# %%
#This is the graph of the pulsar, where we can see that it is dispersed
figure()
imshow(abs(dispersed), extent=[np.amin(np.linspace(0,.15, dis_length)),\
                            np.amax(np.linspace(0,.15, dis_length)),\
                            np.amin(pulse_freqs),\
                            np.amax(pulse_freqs)],\
                              aspect='auto')
axis_labels('time(s)','Frequency (MHz)',  'Dispersed Pulsar (DM=20)')
colorbar(label = 'power')
#savefig("/home/andy/FRB_Pipeline_and_Contributions/gr-transient/documentation/Dispersed_pulsar_DM=20_noisy.png")
#Congrats!, we now have a dispersed pulsar

# %%
figure()
imshow(abs(bb_flipped), extent=[np.amin(np.linspace(0,.15, dis_length)),\
                            np.amax(np.linspace(0,.15, dis_length)),\
                            np.amin(pulse_freqs),\
                            np.amax(pulse_freqs)],\
                              aspect='auto')
axis_labels('time(s)','Frequency (MHz)',  'Dispersed Pulsar (DM=20)')
colorbar(label = 'power')
#savefig("/home/andy/FRB_Pipeline_and_Contributions/gr-transient/documentation/Noise_DM=20_noisy.png")

# %%
( dmk * 25.3 * (inv_f_low_sq - 1/((10*4070/4070 + (1420-5))**2)))

# %%
def dedispersion(DMss, frequency_channels, dispersed_pulse, time_change, n_time, integration_size): 
    """The function takes a set of DMs and dedisperses the given dispersed pulse for all the DMs given."""
    dedispers = np.zeros((len(DMss),dispersed_pulse.shape[0], dispersed_pulse.shape[1]))  #The dedispersed pulse will have the same shape as the dispersed one
    for i in range(len(DMss)):
        dedis = dispersed_pulse*0
        for j in range(frequency_channels):
            dedis[j,:] = np.roll(dispersed_pulse[j,:],-int(round(time_change[i,j]) ))#np.roll shifts 
                #the data over after the last position and reintroduces it to the first position
        dedispers[i,:,:] = dedis
    return dedispers

# %%
((12.1/2)**2*3.14)*(np.pi/180)/.21**2

# %%
5%2

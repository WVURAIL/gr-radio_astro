# %%
# %matplotlib notebook
import struct
import numpy
from matplotlib.pyplot import *
import scipy

# %%
f = scipy.fromfile(open("/home/andy/python_file"), dtype=scipy.float32)
g = scipy.fromfile(open("/home/andy/gnuradio_file"),dtype=scipy.float32)

# %%
f.shape[0]-g.shape[0]
# Out:
# 25200

# %%
plot(f[0:10000])
figure()
plot(np.flip(g[0:100000],0))
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
np.where((g/1.25)==(g/1.25).max())
# Out:
# (array([ 6690, 16690, 26690, 36690, 46690, 56690, 66690]),)

# %%
np.where((f)==(f).max())
# Out:
# (array([ 1153, 11153, 21153, 31153, 41153, 51153, 61153, 71153, 81153,
#         91153]),)

# %%
6690-1153
# Out:
# 5537

# %%
1/.0002
